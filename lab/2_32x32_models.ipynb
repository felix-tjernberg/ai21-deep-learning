# %% [markdown]
# # 2

# %%
from hyper_tuning_helper_functions import (
    model_cnn_2_classes,
    fit_then_evaluate_model
)
from load_datasets import create_generators

train_generator, val_generator = create_generators((32,32))

# %% [markdown]
# ## a)

# %%
model_1__kernel_numbers = [32, 64, 128, 128]
model_1__node_dropout_pairs = [(512, 0)]
model_1 = model_cnn_2_classes(model_1__kernel_numbers, model_1__node_dropout_pairs, name="model_1")
fit_then_evaluate_model(model_1, train_generator, val_generator);
# Out:
# 2022-05-05 10:29:38.637440: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-05 10:29:39.244356: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7395833730697632

# %% [markdown]
# ## b)

# %% [markdown]
# ### Tuning hyper parameters

# %% [markdown]
# ### Trying different kernels numbers

# %%
model_2__kernel_numbers = [32, 64, 128, 256]
model_2 = model_cnn_2_classes(model_2__kernel_numbers, model_1__node_dropout_pairs, name='model_2', flatten_layer_dropout_rate=.5)
fit_then_evaluate_model(model_2, train_generator, val_generator);
# Out:
# 2022-05-04 14:02:24.220934: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 14:02:24.924758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7317708730697632

# %%
model_3__kernel_numbers = [32, 64]
model_3 = model_cnn_2_classes(model_3__kernel_numbers, model_1__node_dropout_pairs, name='model_3', flatten_layer_dropout_rate=.5)
fit_then_evaluate_model(model_3, train_generator, val_generator);
# Out:
# 2022-05-04 14:10:25.822073: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 14:10:26.727072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7109375

# %%
model_4__kernel_numbers = [32]
model_4 = model_cnn_2_classes(model_4__kernel_numbers, model_1__node_dropout_pairs, name='model_4', flatten_layer_dropout_rate=.5)
fit_then_evaluate_model(model_4, train_generator, val_generator);
# Out:
# 2022-05-04 14:13:16.222150: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 14:13:16.764593: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.6848958730697632

# %%
from tensorflow.keras.model import Sequential
from tensorflow.keras.layers import Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam

def model_mlp():
    model = Sequential(
        [
            Flatten(input_shape=(32, 32, 3), name="input_layers"),
            Dropout(0.3),
            Dense(512),
            Dense(1, activation="sigmoid", name="output_layer"),
        ],
        name="mlp_model",
    )
    model.compile(
        loss="binary_crossentropy",
        optimizer=Adam(learning_rate=0.001),
        metrics=["acc"],
    )
    return model
model_5__mlp = model_mlp()
fit_then_evaluate_model(model_5__mlp, train_generator, val_generator);
# Out:
# 2022-05-04 15:13:04.159731: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 15:13:04.681239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.5963541865348816

# %% [markdown]
# ### Testing different mlp layers

# %%
model_6__node_dropout_pairs = [(256, 0)]
model_6 = model_cnn_2_classes(model_1__kernel_numbers, model_6__node_dropout_pairs, name="model_6")
fit_then_evaluate_model(model_6, train_generator, val_generator);
# Out:
# 2022-05-04 15:14:53.865266: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 15:14:54.554026: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7395833730697632

# %%
model_7__node_dropout_pairs = [(256, 0), (128, 0)]
model_7 = model_cnn_2_classes(model_1__kernel_numbers, model_7__node_dropout_pairs, name="model_7")
fit_then_evaluate_model(model_7, train_generator, val_generator);
# Out:
# 2022-05-04 15:34:16.340002: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 15:34:17.124534: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7083333730697632

# %%
model_8__node_dropout_pairs = [(256, .3), (128, 0)]
model_8 = model_cnn_2_classes(model_1__kernel_numbers, model_8__node_dropout_pairs, name="model_8")
fit_then_evaluate_model(model_8, train_generator, val_generator);
# Out:
# 2022-05-04 16:10:53.837269: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:10:54.779097: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7395833730697632

# %%
model_8__node_dropout_pairs = [(256, .3), (128, 0)]
model_8 = model_cnn_2_classes(model_1__kernel_numbers, model_8__node_dropout_pairs, name="model_8", flatten_layer_dropout_rate=.1)
fit_then_evaluate_model(model_8, train_generator, val_generator);
# Out:
# 2022-05-04 16:12:23.097745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:12:23.975465: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7057291865348816

# %%
model_9__node_dropout_pairs = [(128, 0)]
model_9 = model_cnn_2_classes(model_1__kernel_numbers, model_9__node_dropout_pairs, name="model_9", flatten_layer_dropout_rate=.1)
fit_then_evaluate_model(model_9, train_generator, val_generator);
# Out:
# 2022-05-04 16:13:21.030217: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:13:22.249276: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.734375

# %%
model_10__node_dropout_pairs = [(256, 0)]
model_10 = model_cnn_2_classes(model_1__kernel_numbers, model_10__node_dropout_pairs, name="model_10", flatten_layer_dropout_rate=.1)
fit_then_evaluate_model(model_10, train_generator, val_generator);
# Out:
# 2022-05-04 16:14:20.091553: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:14:20.922051: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7109375

# %%
model_11__node_dropout_pairs = [(512, .3), (256, 0)]
model_11 = model_cnn_2_classes(model_1__kernel_numbers, model_11__node_dropout_pairs, name="model_11", flatten_layer_dropout_rate=.1)
fit_then_evaluate_model(model_11, train_generator, val_generator);
# Out:
# 2022-05-04 16:15:24.633373: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:15:25.477287: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7317708730697632

# %%
model_12__node_dropout_pairs = [(512, .3), (256, 0.3), (128, 0)]
model_12 = model_cnn_2_classes(model_1__kernel_numbers, model_12__node_dropout_pairs, name="model_12", flatten_layer_dropout_rate=.1)
fit_then_evaluate_model(model_12, train_generator, val_generator);
# Out:
# 2022-05-04 16:16:50.047415: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:16:51.069752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7395833730697632

# %%
model_10.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_56 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_56 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_57 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_57 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_58 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_59 (Conv2D)          (None, 4, 4, 128)         147584
#
#  max_pooling2d_59 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  flatten_20 (Flatten)        (None, 512)               0
#
#  dropout_47 (Dropout)        (None, 512)               0
#
#  dense_27 (Dense)            (None, 256)               131328
#
#  dropout_48 (Dropout)        (None, 256)               0
#
#  output_layer (Dense)        (None, 1)                 257
#
# ...

# %%
model_9.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_52 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_52 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_53 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_53 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_54 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_55 (Conv2D)          (None, 4, 4, 128)         147584
#
#  max_pooling2d_55 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  flatten_19 (Flatten)        (None, 512)               0
#
#  dropout_45 (Dropout)        (None, 512)               0
#
#  dense_26 (Dense)            (None, 128)               65664
#
#  dropout_46 (Dropout)        (None, 128)               0
#
#  output_layer (Dense)        (None, 1)                 129
#
# ...

# %%
model_8.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_68 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_68 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_69 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_69 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_70 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_71 (Conv2D)          (None, 4, 4, 128)         147584
#
#  max_pooling2d_71 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  flatten_23 (Flatten)        (None, 512)               0
#
#  dropout_54 (Dropout)        (None, 512)               0
#
#  dense_31 (Dense)            (None, 256)               131328
#
#  dropout_55 (Dropout)        (None, 256)               0
#
#  dense_32 (Dense)            (None, 128)               32896
# ...

# %% [markdown]
# ## Testing different strides and sizes

# %%
model_13 = model_cnn_2_classes(model_1__kernel_numbers, model_6__node_dropout_pairs, name="model_13", flatten_layer_dropout_rate=.1, kernel_size=(2,2))
fit_then_evaluate_model(model_13, train_generator, val_generator);
# Out:
# 2022-05-04 16:23:46.972416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:23:47.765758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7447916865348816

# %%
model_14 = model_cnn_2_classes(model_1__kernel_numbers, model_6__node_dropout_pairs, name="model_14", flatten_layer_dropout_rate=.1, kernel_size=(2,2), strides=(1,1))
fit_then_evaluate_model(model_14, train_generator, val_generator);
# Out:
# 2022-05-04 16:27:28.755890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-04 16:27:32.450402: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.515625
