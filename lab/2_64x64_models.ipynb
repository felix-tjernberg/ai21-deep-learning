# %% [markdown]
# # 2

# %% [markdown]
# ## Testing 64x64 images

# %%
from hyper_tuning_helper_functions import (
    model_cnn_2_classes,
    fit_then_evaluate_model
)
from load_datasets import create_generators

# %%
train_generator_64x64, val_generator_64x64 = create_generators((64,64))

model_1__kernel_numbers = [32, 64, 128, 128]
model_1__node_dropout_pairs = [(512, 0)]
model_1 = model_cnn_2_classes(model_1__kernel_numbers, model_1__node_dropout_pairs, name="model_1", input_shape=(64,64,3))
fit_then_evaluate_model(model_1, train_generator_64x64, val_generator_64x64);
# Out:
# 2022-05-05 13:57:06.526652: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-05 13:57:07.613360: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.7526041865348816

# %%
train_generator_150x150_no_transform, val_generator_150x150_no_transform = create_generators((150,150), no_transforms=True)

model_2 = model_cnn_2_classes(model_1__kernel_numbers, model_1__node_dropout_pairs, name="model_2", input_shape=(150,150,3)) 
fit_then_evaluate_model(model_2, train_generator_150x150_no_transform, val_generator_150x150_no_transform, patience=10);
# Out:
# 2022-05-05 13:59:03.970485: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-05 13:59:06.907303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.6927083730697632

# %%
train_generator_250x250_no_transform, val_generator_250x250_no_transform = create_generators((250,250), no_transforms=True)

model_3 = model_cnn_2_classes(model_1__kernel_numbers, model_1__node_dropout_pairs, name="model_3", input_shape=(250,250,3)) 
fit_then_evaluate_model(model_3, train_generator_250x250_no_transform, val_generator_250x250_no_transform, patience=10);
# Out:
# 2022-05-05 14:00:47.150383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-05 14:00:53.540985: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.5104166865348816

# %%
train_generator_64x64_no_transform, val_generator_64x64_no_transform = create_generators((64,64), no_transforms=True)

model_4 = model_cnn_2_classes(model_1__kernel_numbers, model_1__node_dropout_pairs, name="model_4", input_shape=(64,64,3)) 
fit_then_evaluate_model(model_4, train_generator_64x64_no_transform, val_generator_64x64_no_transform, patience=10);
# Out:
# 2022-05-05 14:03:06.461074: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-05 14:03:07.442325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.6536458730697632

# %%
train_generator_32x32_no_transform, val_generator_32x32_no_transform = create_generators((32,32), no_transforms=True)

model_5 = model_cnn_2_classes(model_1__kernel_numbers, model_1__node_dropout_pairs, name="model_5", input_shape=(32,32,3)) 
fit_then_evaluate_model(model_5, train_generator_32x32_no_transform, val_generator_32x32_no_transform, patience=10);
# Out:
# 2022-05-05 14:03:30.994933: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-05 14:03:31.650990: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# val_acc: 0.6822916865348816
