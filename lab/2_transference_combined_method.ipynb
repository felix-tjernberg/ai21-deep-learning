# %% [markdown]
# # 2d

# %% [markdown]
# ## Transference combined model method

# %%
from hyper_tuning_helper_functions import (
    model_transference_2_classes_combined_method,
    fit_then_evaluate_model
)
from load_datasets import create_generators

# %%
from tensorflow.keras.applications import Xception

Xception_model = Xception(weights="imagenet", include_top=False, input_shape=(299, 299, 3))

train_generator_299x299, val_generator_299x299 = create_generators((299,299))

model_1__node_dropout_pairs = [(512, 0.3)]
model_1 = model_transference_2_classes_combined_method(Xception_model, model_1__node_dropout_pairs, name="model_1")
fit_then_evaluate_model(model_1, train_generator_299x299, val_generator_299x299, model_fit_verbosity=1);
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-05-11 14:33:30.271487: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-11 14:33:30.271592: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/100000
# 2022-05-11 14:33:34.429433: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-11 14:33:35.619275: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 50/50 [==============================] - ETA: 0s - loss: 3.8644 - acc: 0.9125
# ...
